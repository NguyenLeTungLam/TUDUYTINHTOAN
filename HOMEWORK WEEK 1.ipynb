# %%
#bai6
kitu = input("nhap 1 ki tu:") 
if len(kitu) != 1:
    print("vui long nhap 1 ki tu")
else:
      if kitu.isalpha():
        print("day la 1 chu cai")
      elif kitu.isdigit():
        print("day la 1 con so")
      else:
        print("day k phai la chu cai va so")
# Out:
# day la 1 con so

# %% [markdown]
# Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó
# là số chẵn hay số lẻ.

# %%
#bai1
a = int(input("nhap 1 so bat ki:"))
if a % 2 == 0:
    print("day la so chan")
else:
    print("day la so le")
# Out:
# day la so le

# %% [markdown]
# Kiểm tra số có tận cùng 5 không: Viết chương trình nhập một số nguyên, kiểm tra
# số đó có tận cùng 5 không, nếu đúng in ra “True”, nếu sai in ra “False”

# %%
#bai2
a = int(input("nhap 1 so:"))
if a % 3 == 0:
    print("true")
elif a % 5 == 0:
    print("true")
else:
    print("false")
# Out:
# false

# %% [markdown]
# Kiểm tra tuổi đủ điều kiện bầu cử: Viết chương trình nhập năm sinh của một
# người, kiểm tra xem người đó có đủ 18 tuổi để đi bầu cử hay không.

# %%
#bai4
a = int(input("nhap so tuoi:"))
if a >= 18:
    print("da du tuoi di bau cu")
else:
    print("chua du tuoi bau cu")
# Out:
# chua du tuoi bau cu

# %% [markdown]
# So sánh 2 số: Viết chương trình nhập vào hai số, in ra số lớn hơn hoặc thông báo
# nếu hai số bằng nhau.

# %%
#bai5
a = int(input("nhap so dau"))
b = int(input("nhap so thu 2"))
if a > b:
    print("so lon hon la:" , a)
elif a < b:
    print("so lon hon la:" , b)
else:
    print("ca hai so bang nhau")
# Out:
# so lon hon la: 7

# %% [markdown]
# Tính điểm học lực
# Nhập điểm (0-10), phân loại học lực theo quy tắc:
# >=8: Giỏi; >=6.5 và <8: Khá; >=5 và <6.5: Trung bình; <5: Yếu

# %%
a = float(input("nhap diem so:"))
if a < 0 or a > 10:
    print("diem k hop le vui long nhap diem tu 0-10!")
else:
    if a >= 8:
        print("hoc luc gioi")
    elif a >= 6.5 and a < 8:
        print("hoc luc kha")
    elif a < 6.5 and a >= 5:
        print("hoc luc trung binh")
    else:
        print("hoc luc yeu")
# Out:
# diem k hop le vui long nhap diem tu 0-10!

# %% [markdown]
# Kiểm tra năm nhuận: Viết chương trình nhập năm, kiểm tra xem năm đó có phải
# năm nhuận hay không. (Năm nhuận nếu chia hết cho 400 hoặc chia hết cho 4
# nhưng không chia hết cho 100)

# %%
a = int(input("nhap so nam:"))
if a % 400 == 0:
    print("day la nam nhuan")
elif a % 4 == 0 and a % 100 != 0:
    print("day la nam nhuan")
else:
    print("day k phai nam nhuan")
# Out:
# day la nam nhuan

# %% [markdown]
# Chuyển đổi số thành chữ số: Nhập một số nguyên từ 0 đến 9, in ra tên chữ số
# tương ứng (0 -> "Không", 1 -> "Một", ...) – Xem trước match …case

# %%
try:

 a = int(input("nhap 1 so nguyen:"))

 match a:
    case 0:
        print('khong')
    case 1:
        print("mot")
    case 2:
        print("hai")
    case 3:
        print("ba")
    case 4:
        print("bon")
    case 5:
        print("nam")
    case 6:
        print("sau")
    case 7:
        print("bay")
    case 8:
        print("tam")
    case 9:
        print("chin")
    case _:
        print("vui long nhap so tu 0-9")
except ValueError:
    print("vui long chi nhap 1 so nguyen")
# Out:
# sau

# %% [markdown]
# Kiểm tra điểm thi xem có qua môn hay phải học lại: Nhập điểm thi, nếu điểm >=
# 4 thì in "Qua môn", ngược lại in "Học lại".

# %%
a = float(input("nhap diem thi"))
if a >= 4:
    print("qua mon")
else:
    print("hoc lai")
# Out:
# hoc lai

# %% [markdown]
# Kiểm tra năm sinh và tính tuổi: Nhập năm sinh, tính tuổi hiện tại (giả sử năm
# hiện tại là 2025), và kiểm tra xem người đó có đủ 18 tuổi hay chưa

# %%
a = int(input("nhap nam sinh"))
tuoi = 2025 - a
print("tuoi hien tai la:", tuoi)
if tuoi >= 18:
    print("da du tuoi")
else:
    print("chua du tuoi")
# Out:
# tuoi hien tai la: 18
# da du tuoi

# %% [markdown]
# Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu
# vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần
# diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân.

# %%
a = float(input("nhap chieu rong:"))
b = float(input("nhap chieu dai:"))
dientichhcn = a * b
if a < b:
    print("dien tich hcn la:", dientichhcn)
    r = a / 2 
    print("ban kinh la:",r)
    dientichhc = 3.14 * (r**2)
    print("dien tich hinh tron la:",dientichhc)
    dientichtrongcay = dientichhcn - dientichhc
    print("dien tich trong cay la:", dientichtrongcay)

else:
    print("chieu dai phai lon hon chieu rong")
# Out:
# dien tich hcn la: 648.0
# ban kinh la: 9.0
# dien tich hinh tron la: 254.34
# dien tich trong cay la: 393.65999999999997
