# %% [markdown]
# Viết hàm truyền vào hai số nguyên a, b. Trả về số lớn hơn trong hai số. def Max_Of_Two( a, b) ->
# int:

# %%
# Out:
# Sau khi hoán đổi: x = 10, y = 5

# %%
def comparebmi(w1 , h1 , w2 , h2) -> int:
    bmi1 = w1 / (h1 * h1)
    bmi2 = w2 / (h2 * h2)
    if bmi1 > bmi2:
        return 1
    elif bmi < bmi2:
        return 2
    else:
        return 0
w1 , h1 = map(int , input().split())
w2 , h2 = map(int , input().split())
if comparebmi(w1 , h1 , w2 , h2) == 1:
    print("1 beo hon 2")
elif (w1 , h1 , w2 , h2) == 2:
    print("2 beo hon 1")
else:
    print("2 ban nhau")
# Out:
# 1 beo hon 2

# %%
def grade(s):
grade = float(input())
if
