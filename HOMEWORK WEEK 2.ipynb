# %% [markdown]
#  Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó

# %%
a = float(input("nhap chieu dai:"))
b = float(input("nhap chieu rong:"))
if a > b:
    chuvi = a + b
    dientich = a * b
    print(f"chu vi la: {chuvi} dientichla: {dientich}")
else:
    print("chieu dai phai lon hon chieu rong")
# Out:
# chu vi la: 11.0 dientichla: 30.0

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
a = float(input("nhap ban kinh hinh tron:"))
chuvi = 3.14 * a 
dientich = 3.14 * (a**2)
print(f"chu vi bang: {chuvi} , dien tich bang: {dientich}")
# Out:
# chu vi bang: 14.13 , dien tich bang: 63.585

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình

# %%
a = float(input("nhap canh a"))
b = float(input("nhap canh b:"))
c = float(input("nhap canh c:"))

# %% [markdown]
# Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
try:
    a = float(input("Nhập hệ số a: "))
    b = float(input("Nhập hệ số b: "))

    print(f"Phương trình: {a}x + {b} = 0")

    if a != 0:
        x = -b / a
        # Làm tròn 2 chữ số thập phân cho gọn
        print(f"Phuong trinh co nghiem duy nhat: x = {round(x, 2)}")
    else:
        if b == 0:
            print("Phuong trinh co vo so nghiem")
        else:
            print("Phuong trinh vo nghiem")

except ValueError:
    print("Vui lòng nhập số thực hợp lệ!")
# Out:
# Phương trình: 7.0x + 7.0 = 0
# Phuong trinh co nghiem duy nhat: x = -1.0

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a , b , c , d = map(int , input().split())
max = max(a , b , c , d)
print(max)
# Out:
# 5

# %% [markdown]
# Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
x = int(input())
phut = x / 60
gio = phut / 60
print(f"giay la:{x:.2f}, gio la:{gio:.2f}, phut la:{phut:.2f}")
# Out:
# giay la:36.00, gio la:0.01, phut la:0.60

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a , b , c , d = map(int , input().split())
min = min(a , b , c , d)
print(min)
# Out:
# 3

# %% [markdown]
# Bài 11: Tính x
# y (Với x, y là số thực).

# %%
x , y = map(int , input().split())
ketqua = x ** y
print(ketqua)
# Out:
# 243
